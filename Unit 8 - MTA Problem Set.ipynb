# %% [markdown]
# 1.Save the Saturday, June 17th, 2017 data to a csv file. You can find it here: http://web.mta.info/developers/turnstile.html and read it in using read_csv. View the head of the dataframe.

# %%
#insert 1
import pandas as pd
MTA = pd.read_csv('june17.csv')
MTA.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6215258
# 1  REGULAR  6215284
# 2  REGULAR  6215318
# 3  REGULAR  6215475
# 4  REGULAR  6215841
#
#    EXITS
# 0                                            2104297
# 1                                            2104303
# 2                                            2104337
# 3                                            2104417
# 4                                            2104465

# %%
# This is for the report later:
# Out:
# 15776 6 ORCHARD BEACH
# 15777 6 ORCHARD BEACH
# 15778 6 ORCHARD BEACH
# 15779 6 ORCHARD BEACH
# 15780 6 ORCHARD BEACH
# 15781 6 ORCHARD BEACH
# 15782 6 ORCHARD BEACH
# 15783 6 ORCHARD BEACH
# 15784 6 ORCHARD BEACH
# 15785 6 ORCHARD BEACH
# 15786 6 ORCHARD BEACH
# 15787 6 ORCHARD BEACH
# 15788 6 ORCHARD BEACH
# 15789 6 ORCHARD BEACH
# 15790 6 ORCHARD BEACH
# 15791 6 ORCHARD BEACH
# 15792 6 ORCHARD BEACH
# 15793 6 ORCHARD BEACH
# 15794 6 ORCHARD BEACH
# 15795 6 ORCHARD BEACH
# 15796 6 ORCHARD BEACH
# 15797 6 ORCHARD BEACH
# 15798 6 ORCHARD BEACH
# 15799 6 ORCHARD BEACH
# 15800 6 ORCHARD BEACH
# 15801 6 ORCHARD BEACH
# 15802 6 ORCHARD BEACH
# 15803 6 ORCHARD BEACH
# 15804 6 ORCHARD BEACH
# 15805 6 ORCHARD BEACH
# 21076 6 SPRING ST
# 21077 6 SPRING ST
# 21078 6 SPRING ST
# 21079 6 SPRING ST
# 21080 6 SPRING ST
# 21081 6 SPRING ST
# 21082 6 SPRING ST
# 21083 6 SPRING ST
# 21084 6 SPRING ST
# 21085 6 SPRING ST
# 21086 6 SPRING ST
# 21087 6 SPRING ST
# 21088 6 SPRING ST
# 21089 6 SPRING ST
# 21090 6 SPRING ST
# 21091 6 SPRING ST
# 21092 6 SPRING ST
# 21093 6 SPRING ST
# 21094 6 SPRING ST
# 21095 6 SPRING ST
# 21096 6 SPRING ST
# 21097 6 SPRING ST
# 21098 6 SPRING ST
# 21099 6 SPRING ST
# 21100 6 SPRING ST
# 21101 6 SPRING ST
# 21102 6 SPRING ST
# 21103 6 SPRING ST
# 21104 6 SPRING ST
# 21105 6 SPRING ST
# 21106 6 SPRING ST
# 21107 6 SPRING ST
# 21108 6 SPRING ST
# 21109 6 SPRING ST
# 21110 6 SPRING ST
# 21111 6 SPRING ST
# 21166 6 ASTOR PL
# 21167 6 ASTOR PL
# 21168 6 ASTOR PL
# 21169 6 ASTOR PL
# 21170 6 ASTOR PL
# 21171 6 ASTOR PL
# 21172 6 ASTOR PL
# 21173 6 ASTOR PL
# 21174 6 ASTOR PL
# 21175 6 ASTOR PL
# 21176 6 ASTOR PL
# 21177 6 ASTOR PL
# 21178 6 ASTOR PL
# 21179 6 ASTOR PL
# 21180 6 ASTOR PL
# 21181 6 ASTOR PL
# 21182 6 ASTOR PL
# 21183 6 ASTOR PL
# 21184 6 ASTOR PL
# 21185 6 ASTOR PL
# 21186 6 ASTOR PL
# 21187 6 ASTOR PL
# 21188 6 ASTOR PL
# 21189 6 ASTOR PL
# 21190 6 ASTOR PL
# 21191 6 ASTOR PL
# 21192 6 ASTOR PL
# 21193 6 ASTOR PL
# 21194 6 ASTOR PL
# 21195 6 ASTOR PL
# 21196 6 ASTOR PL
# 21197 6 ASTOR PL
# 21198 6 ASTOR PL
# 21199 6 ASTOR PL
# 21200 6 ASTOR PL
# 21201 6 ASTOR PL
# 21202 6 ASTOR PL
# 21203 6 ASTOR PL
# 21204 6 ASTOR PL
# 21205 6 ASTOR PL
# 21206 6 ASTOR PL
# 21207 6 ASTOR PL
# 21208 6 ASTOR PL
# 21209 6 ASTOR PL
# 21210 6 ASTOR PL
# 21211 6 ASTOR PL
# 21212 6 ASTOR PL
# 21213 6 ASTOR PL
# 21214 6 ASTOR PL
# 21215 6 ASTOR PL
# 21216 6 ASTOR PL
# 21217 6 ASTOR PL
# 21218 6 ASTOR PL
# 21219 6 ASTOR PL
# 21220 6 ASTOR PL
# 21221 6 ASTOR PL
# 21222 6 ASTOR PL
# 21223 6 ASTOR PL
# 21224 6 ASTOR PL
# 21225 6 ASTOR PL
# 21226 6 ASTOR PL
# 21227 6 ASTOR PL
# 21228 6 ASTOR PL
# 21229 6 ASTOR PL
# 21230 6 ASTOR PL
# 21231 6 ASTOR PL
# 21232 6 ASTOR PL
# 21233 6 ASTOR PL
# 21234 6 ASTOR PL
# 21235 6 ASTOR PL
# 21236 6 ASTOR PL
# 21308 6 23 ST
# 21309 6 23 ST
# 21310 6 23 ST
# 21311 6 23 ST
# 21312 6 23 ST
# 21313 6 23 ST
# 21314 6 23 ST
# 21315 6 23 ST
# 21316 6 23 ST
# 21317 6 23 ST
# 21318 6 23 ST
# 21319 6 23 ST
# 21320 6 23 ST
# 21321 6 23 ST
# 21322 6 23 ST
# 21323 6 23 ST
# 21324 6 23 ST
# 21325 6 23 ST
# 21326 6 23 ST
# 21327 6 23 ST
# 21328 6 23 ST
# 21329 6 23 ST
# 21330 6 23 ST
# 21331 6 23 ST
# 21332 6 23 ST
# 21333 6 23 ST
# 21334 6 23 ST
# 21335 6 23 ST
# 21336 6 23 ST
# 21337 6 23 ST
# 21338 6 23 ST
# 21339 6 23 ST
# 21340 6 23 ST
# 21341 6 23 ST
# 21342 6 23 ST
# 21343 6 23 ST
# 21344 6 23 ST
# 21345 6 23 ST
# 21346 6 23 ST
# 21347 6 23 ST
# 21348 6 23 ST
# 21349 6 23 ST
# 21350 6 23 ST
# 21351 6 23 ST
# 21352 6 23 ST
# 21353 6 23 ST
# 21354 6 23 ST
# 21355 6 23 ST
# 21356 6 23 ST
# 21357 6 23 ST
# 21358 6 23 ST
# 21359 6 23 ST
# 21360 6 23 ST
# 21361 6 23 ST
# 21362 6 23 ST
# 21489 6 28 ST
# 21490 6 28 ST
# 21491 6 28 ST
# 21492 6 28 ST
# 21493 6 28 ST
# 21494 6 28 ST
# 21495 6 28 ST
# 21496 6 28 ST
# 21497 6 28 ST
# 21498 6 28 ST
# 21499 6 28 ST
# 21500 6 28 ST
# 21501 6 28 ST
# 21502 6 28 ST
# 21503 6 28 ST
# 21504 6 28 ST
# 21505 6 28 ST
# 21506 6 28 ST
# 21507 6 28 ST
# 21508 6 28 ST
# 21509 6 28 ST
# 21510 6 28 ST
# 21511 6 28 ST
# 21512 6 28 ST
# 21513 6 28 ST
# 21514 6 28 ST
# 21515 6 28 ST
# 21516 6 28 ST
# 21517 6 28 ST
# 21518 6 28 ST
# 21519 6 28 ST
# 21520 6 28 ST
# 21521 6 28 ST
# 21522 6 28 ST
# 21523 6 28 ST
# 21524 6 28 ST
# 21525 6 28 ST
# 21526 6 28 ST
# 21527 6 28 ST
# 21528 6 28 ST
# 21529 6 28 ST
# 21530 6 28 ST
# 21531 6 28 ST
# 21532 6 28 ST
# 21533 6 28 ST
# 21534 6 28 ST
# 21535 6 28 ST
# 21536 6 28 ST
# 21537 6 28 ST
# 21538 6 28 ST
# 21539 6 28 ST
# 21540 6 28 ST
# 21541 6 28 ST
# 21542 6 28 ST
# 21543 6 28 ST
# 21544 6 28 ST
# 21545 6 28 ST
# 21546 6 28 ST
# 21547 6 28 ST
# 21548 6 28 ST
# 21549 6 28 ST
# 21550 6 28 ST
# 21551 6 28 ST
# 21552 6 28 ST
# 21553 6 28 ST
# 21554 6 28 ST
# 21555 6 28 ST
# 21556 6 28 ST
# 21557 6 28 ST
# 21558 6 28 ST
# 21559 6 28 ST
# 21560 6 28 ST
# 21561 6 28 ST
# 21562 6 28 ST
# 21563 6 28 ST
# 21564 6 28 ST
# 21565 6 28 ST
# 21566 6 28 ST
# 21567 6 33 ST
# 21568 6 33 ST
# 21569 6 33 ST
# 21570 6 33 ST
# 21571 6 33 ST
# 21572 6 33 ST
# 21573 6 33 ST
# 21574 6 33 ST
# 21575 6 33 ST
# 21576 6 33 ST
# 21577 6 33 ST
# 21578 6 33 ST
# 21579 6 33 ST
# 21580 6 33 ST
# 21581 6 33 ST
# 21582 6 33 ST
# 21583 6 33 ST
# 21584 6 33 ST
# 21585 6 33 ST
# 21586 6 33 ST
# 21587 6 33 ST
# 21588 6 33 ST
# 21589 6 33 ST
# 21590 6 33 ST
# 21591 6 33 ST
# 21592 6 33 ST
# 21593 6 33 ST
# 21594 6 33 ST
# 21595 6 33 ST
# 21596 6 33 ST
# 21597 6 33 ST
# 21598 6 33 ST
# 21599 6 33 ST
# 21600 6 33 ST
# 21601 6 33 ST
# 21602 6 33 ST
# 21603 6 33 ST
# 21604 6 33 ST
# 21605 6 33 ST
# 21606 6 33 ST
# 21607 6 33 ST
# 21608 6 33 ST
# 21609 6 33 ST
# 21610 6 33 ST
# 21611 6 33 ST
# 21612 6 33 ST
# 21613 6 33 ST
# 21614 6 33 ST
# 21615 6 33 ST
# 21616 6 33 ST
# 21617 6 33 ST
# 21618 6 33 ST
# 21619 6 33 ST
# 21620 6 33 ST
# 21621 6 33 ST
# 21622 6 33 ST
# 21623 6 33 ST
# 21624 6 33 ST
# 21625 6 33 ST
# 21626 6 33 ST
# 21627 6 33 ST
# 21628 6 33 ST
# 21629 6 33 ST
# 21630 6 33 ST
# 21631 6 33 ST
# 21632 6 33 ST
# 21633 6 33 ST
# 21634 6 33 ST
# 21635 6 33 ST
# 21636 6 33 ST
# 21637 6 33 ST
# 21638 6 33 ST
# 21639 6 33 ST
# 21640 6 33 ST
# 21641 6 33 ST
# 21642 6 33 ST
# 21643 6 33 ST
# 21644 6 33 ST
# 21645 6 33 ST
# 21646 6 33 ST
# 21647 6 33 ST
# 21648 6 33 ST
# 21649 6 33 ST
# 21650 6 33 ST
# 21651 6 33 ST
# 21652 6 33 ST
# 21653 6 33 ST
# 21654 6 33 ST
# 21655 6 33 ST
# 21656 6 33 ST
# 21657 6 33 ST
# 21658 6 33 ST
# 21659 6 33 ST
# 21660 6 33 ST
# 21661 6 33 ST
# 21662 6 33 ST
# 21663 6 33 ST
# 21664 6 33 ST
# 21665 6 33 ST
# 21666 6 33 ST
# 21667 6 33 ST
# 21668 6 33 ST
# 21669 6 33 ST
# 21670 6 33 ST
# 21671 6 33 ST
# 21672 6 33 ST
# 21673 6 33 ST
# 21674 6 33 ST
# 21675 6 33 ST
# 21676 6 33 ST
# 21677 6 33 ST
# 21678 6 33 ST
# 21679 6 33 ST
# 21680 6 33 ST
# 21681 6 33 ST
# 21682 6 33 ST
# 21683 6 33 ST
# 21684 6 33 ST
# 21685 6 33 ST
# 21686 6 33 ST
# 21687 6 33 ST
# 21688 6 33 ST
# 21689 6 33 ST
# 21690 6 33 ST
# 21691 6 33 ST
# 21692 6 33 ST
# 21693 6 33 ST
# 21694 6 33 ST
# 21695 6 33 ST
# 21696 6 33 ST
# 21697 6 33 ST
# 22106 6 51 ST
# 22107 6 51 ST
# 22108 6 51 ST
# 22109 6 51 ST
# 22110 6 51 ST
# 22111 6 51 ST
# 22112 6 51 ST
# 22113 6 51 ST
# 22114 6 51 ST
# 22115 6 51 ST
# 22116 6 51 ST
# 22117 6 51 ST
# 22118 6 51 ST
# 22119 6 51 ST
# 22120 6 51 ST
# 22121 6 51 ST
# 22122 6 51 ST
# 22123 6 51 ST
# 22124 6 51 ST
# 22125 6 51 ST
# 22126 6 51 ST
# 22127 6 51 ST
# 22128 6 51 ST
# 22129 6 51 ST
# 22130 6 51 ST
# 22131 6 51 ST
# 22132 6 51 ST
# 22133 6 51 ST
# 22134 6 51 ST
# 22135 6 51 ST
# 22136 6 51 ST
# 22137 6 51 ST
# 22138 6 51 ST
# 22139 6 51 ST
# 22140 6 51 ST
# 22141 6 51 ST
# 22142 6 51 ST
# 22143 6 51 ST
# 22144 6 51 ST
# 22145 6 51 ST
# 22146 6 51 ST
# 22147 6 51 ST
# 22148 6 51 ST
# 22149 6 51 ST
# 22150 6 51 ST
# 22151 6 51 ST
# 22152 6 51 ST
# 22153 6 51 ST
# 22154 6 51 ST
# 22155 6 51 ST
# 22156 6 51 ST
# 22157 6 51 ST
# 22158 6 51 ST
# 22159 6 51 ST
# 22160 6 51 ST
# 22161 6 51 ST
# 22162 6 51 ST
# 22163 6 51 ST
# 22164 6 51 ST
# 22165 6 51 ST
# 22166 6 51 ST
# 22167 6 51 ST
# 22168 6 51 ST
# 22169 6 51 ST
# 22170 6 51 ST
# 22171 6 51 ST
# 22172 6 51 ST
# 22173 6 51 ST
# 22174 6 51 ST
# 22175 6 51 ST
# 22176 6 51 ST
# 22177 6 51 ST
# 22178 6 51 ST
# 22179 6 51 ST
# 22180 6 51 ST
# 22181 6 51 ST
# 22182 6 51 ST
# 22183 6 51 ST
# 22184 6 51 ST
# 22185 6 51 ST
# 22186 6 51 ST
# 22187 6 51 ST
# 22188 6 51 ST
# 22189 6 51 ST
# 22190 6 51 ST
# 22191 6 51 ST
# 22192 6 51 ST
# 22193 6 51 ST
# 22194 6 51 ST
# 22195 6 51 ST
# 22196 6 51 ST
# 22197 6 51 ST
# 22198 6 51 ST
# 22199 6 51 ST
# 22200 6 51 ST
# 22201 6 51 ST
# 22202 6 51 ST
# 22203 6 51 ST
# 22204 6 51 ST
# 22205 6 51 ST
# 22206 6 51 ST
# 22207 6 51 ST
# 22208 6 51 ST
# 22209 6 51 ST
# 22210 6 51 ST
# 22211 6 51 ST
# 22212 6 51 ST
# 22213 6 51 ST
# 22214 6 51 ST
# 22215 6 51 ST
# 22216 6 51 ST
# 22217 6 51 ST
# 22218 6 51 ST
# 22219 6 51 ST
# 22220 6 51 ST
# 22221 6 51 ST
# 22222 6 51 ST
# 22223 6 51 ST
# 22224 6 51 ST
# 22225 6 51 ST
# 22226 6 51 ST
# 22227 6 51 ST
# 22228 6 51 ST
# 22229 6 51 ST
# 22230 6 51 ST
# 22231 6 51 ST
# 22232 6 51 ST
# 22233 6 51 ST
# 22234 6 51 ST
# 22235 6 51 ST
# 22236 6 51 ST
# 22237 6 51 ST
# 22238 6 51 ST
# 22239 6 51 ST
# 22240 6 51 ST
# 22241 6 51 ST
# 22242 6 51 ST
# 22243 6 51 ST
# 22436 6 68ST-HUNTER CO
# 22437 6 68ST-HUNTER CO
# 22438 6 68ST-HUNTER CO
# 22439 6 68ST-HUNTER CO
# 22440 6 68ST-HUNTER CO
# 22441 6 68ST-HUNTER CO
# 22442 6 68ST-HUNTER CO
# 22443 6 68ST-HUNTER CO
# 22444 6 68ST-HUNTER CO
# 22445 6 68ST-HUNTER CO
# 22446 6 68ST-HUNTER CO
# 22447 6 68ST-HUNTER CO
# 22448 6 68ST-HUNTER CO
# 22449 6 68ST-HUNTER CO
# 22450 6 68ST-HUNTER CO
# 22451 6 68ST-HUNTER CO
# 22452 6 68ST-HUNTER CO
# 22453 6 68ST-HUNTER CO
# 22454 6 68ST-HUNTER CO
# 22455 6 68ST-HUNTER CO
# 22546 6 77 ST
# 22547 6 77 ST
# 22548 6 77 ST
# 22549 6 77 ST
# 22550 6 77 ST
# 22551 6 77 ST
# 22552 6 77 ST
# 22553 6 77 ST
# 22554 6 77 ST
# 22555 6 77 ST
# 22556 6 77 ST
# 22557 6 77 ST
# 22558 6 77 ST
# 22559 6 77 ST
# 22560 6 77 ST
# 22561 6 77 ST
# 22562 6 77 ST
# 22563 6 77 ST
# 22564 6 77 ST
# 22565 6 77 ST
# 22566 6 77 ST
# 22567 6 77 ST
# 22568 6 77 ST
# 22569 6 77 ST
# 22570 6 77 ST
# 22571 6 77 ST
# 22572 6 77 ST
# 22573 6 77 ST
# 22574 6 77 ST
# 22575 6 77 ST
# 22576 6 77 ST
# 22577 6 77 ST
# 22578 6 77 ST
# 22579 6 77 ST
# 22580 6 77 ST
# 22581 6 77 ST
# 22582 6 77 ST
# 22583 6 77 ST
# 22584 6 77 ST
# 22585 6 77 ST
# 22586 6 77 ST
# 22587 6 77 ST
# 22588 6 77 ST
# 22589 6 77 ST
# 22590 6 77 ST
# 22591 6 77 ST
# 22592 6 77 ST
# 22593 6 77 ST
# 22594 6 77 ST
# 22595 6 77 ST
# 22596 6 77 ST
# 22597 6 77 ST
# 22598 6 77 ST
# 22599 6 77 ST
# 22600 6 77 ST
# 22601 6 77 ST
# 22602 6 77 ST
# 22603 6 77 ST
# 22604 6 77 ST
# 22605 6 77 ST
# 22606 6 77 ST
# 22607 6 77 ST
# 22608 6 77 ST
# 22609 6 77 ST
# 22742 6 96 ST
# 22743 6 96 ST
# 22744 6 96 ST
# 22745 6 96 ST
# 22746 6 96 ST
# 22747 6 96 ST
# 22748 6 96 ST
# 22749 6 96 ST
# 22750 6 96 ST
# 22751 6 96 ST
# 22752 6 96 ST
# 22753 6 96 ST
# 22754 6 96 ST
# 22755 6 96 ST
# 22756 6 96 ST
# 22757 6 96 ST
# 22758 6 96 ST
# 22759 6 96 ST
# 22760 6 96 ST
# 22761 6 96 ST
# 22762 6 96 ST
# 22763 6 96 ST
# 22764 6 96 ST
# 22765 6 96 ST
# 22766 6 96 ST
# 22767 6 96 ST
# 22768 6 96 ST
# 22769 6 96 ST
# 22770 6 96 ST
# 22771 6 96 ST
# 22772 6 96 ST
# 22773 6 96 ST
# 22774 6 96 ST
# 22775 6 96 ST
# 22776 6 96 ST
# 22777 6 96 ST
# 22778 6 103 ST
# 22779 6 103 ST
# 22780 6 103 ST
# 22781 6 103 ST
# 22782 6 103 ST
# 22783 6 103 ST
# 22784 6 103 ST
# 22785 6 103 ST
# 22786 6 103 ST
# 22787 6 103 ST
# 22788 6 103 ST
# 22789 6 103 ST
# 22790 6 103 ST
# 22791 6 103 ST
# 22792 6 103 ST
# 22793 6 103 ST
# 22794 6 103 ST
# 22795 6 103 ST
# 22796 6 103 ST
# 22797 6 103 ST
# 22798 6 103 ST
# 22799 6 103 ST
# 22800 6 103 ST
# 22801 6 103 ST
# 22802 6 103 ST
# 22803 6 103 ST
# 22804 6 103 ST
# 22805 6 103 ST
# 22806 6 103 ST
# 22807 6 103 ST
# 22808 6 103 ST
# 22809 6 103 ST
# 22810 6 103 ST
# 22811 6 103 ST
# 22812 6 103 ST
# 22813 6 103 ST
# 22814 6 110 ST
# 22815 6 110 ST
# 22816 6 110 ST
# 22817 6 110 ST
# 22818 6 110 ST
# 22819 6 110 ST
# 22820 6 110 ST
# 22821 6 110 ST
# 22822 6 110 ST
# 22823 6 110 ST
# 22824 6 110 ST
# 22825 6 110 ST
# 22826 6 110 ST
# 22827 6 110 ST
# 22828 6 110 ST
# 22829 6 110 ST
# 22830 6 110 ST
# 22831 6 110 ST
# 22832 6 110 ST
# 22833 6 110 ST
# 22834 6 110 ST
# 22835 6 110 ST
# 22836 6 110 ST
# 22837 6 110 ST
# 22838 6 110 ST
# 22839 6 110 ST
# 22840 6 110 ST
# 22841 6 110 ST
# 22842 6 110 ST
# 22843 6 110 ST
# 22844 6 110 ST
# 22845 6 110 ST
# 22846 6 110 ST
# 22847 6 110 ST
# 22848 6 110 ST
# 22849 6 110 ST
# 22850 6 116 ST
# 22851 6 116 ST
# 22852 6 116 ST
# 22853 6 116 ST
# 22854 6 116 ST
# 22855 6 116 ST
# 22856 6 116 ST
# 22857 6 116 ST
# 22858 6 116 ST
# 22859 6 116 ST
# 22860 6 116 ST
# 22861 6 116 ST
# 22862 6 116 ST
# 22863 6 116 ST
# 22864 6 116 ST
# 22865 6 116 ST
# 22866 6 116 ST
# 22867 6 116 ST
# 22868 6 116 ST
# 22869 6 116 ST
# 22870 6 116 ST
# 22871 6 116 ST
# 22872 6 116 ST
# 22873 6 116 ST
# 22874 6 116 ST
# 22875 6 116 ST
# 22876 6 116 ST
# 22877 6 116 ST
# 22878 6 116 ST
# 22879 6 116 ST
# 22880 6 116 ST
# 22881 6 116 ST
# 22882 6 116 ST
# 22883 6 116 ST
# 22884 6 116 ST
# 22885 6 116 ST
# 22886 6 116 ST
# 22887 6 116 ST
# 22888 6 116 ST
# 22889 6 116 ST
# 22890 6 116 ST
# 22891 6 116 ST
# 22892 6 116 ST
# 22893 6 116 ST
# 22894 6 116 ST
# 22895 6 116 ST
# 22896 6 116 ST
# 22897 6 116 ST
# 24414 6 3 AV 138 ST
# 24415 6 3 AV 138 ST
# 24416 6 3 AV 138 ST
# 24417 6 3 AV 138 ST
# 24418 6 3 AV 138 ST
# 24419 6 3 AV 138 ST
# 24420 6 3 AV 138 ST
# 24421 6 3 AV 138 ST
# 24422 6 3 AV 138 ST
# 24423 6 3 AV 138 ST
# 24424 6 3 AV 138 ST
# 24425 6 3 AV 138 ST
# 24426 6 3 AV 138 ST
# 24427 6 3 AV 138 ST
# 24428 6 3 AV 138 ST
# 24429 6 3 AV 138 ST
# 24430 6 3 AV 138 ST
# 24431 6 3 AV 138 ST
# 24432 6 3 AV 138 ST
# 24433 6 3 AV 138 ST
# 24434 6 3 AV 138 ST
# 24435 6 3 AV 138 ST
# 24436 6 3 AV 138 ST
non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# 4.In one line, print out the unique STATION names. How many are there? (Hint: use set).

# %%
#insert 4
words = []
for column in MTA.LINENAME:
    words.append(column)
print((set(words)))
# Out:
# {'ACEL', 'FJMZ', 'ACS', '4', '25', '2345ACJZ', 'NQR456W', '6', '1', '1AC', 'D', 'CE', 'BDE', 'FQ', '4567S', '2', 'NQRW', '7NQW', 'ACENGRS1237W', 'ACE', 'S', 'F', 'BDFM7', 'MR', 'LNQR456W', '5', 'JM', 'EMG', 'L', 'EF', '23ACE', 'R', 'FLM123', 'BC', 'ND', 'BDFQ6', '245', '1237ACENQRS', 'FM', 'M', 'EM6', 'C', 'FG', 'LM', 'EM', 'E', 'ABCD1', '456JZ', '34', 'R2345', 'ACF', 'J', '123', '2345BDNQR', 'BDNQR', 'JMZ', 'DNR', '23', '4BD', '1RW', 'G', 'ACBD', 'JZ', 'NRW', 'NQW', 'ABCDEFM', 'BDFM', 'JNQRZ6W', 'BQ', '123FLM', 'BQS', 'GL', 'AC1', '2345R', 'ABCD', 'LG', '456LNQRW', 'BDNQR2345', 'JZ456', '7EFMR', 'ACJZ2345', '3', 'S2345', 'DFGMNR', 'BD', '2345', 'AS', 'A', 'ACENQRS1237W', 'ACG', '123ACE', '456NQRW', 'R1W', '2345S', 'ACJLZ', 'BD4', '7', 'DFNQ', 'EJZ', '6DF', 'Q', '1ABCD', 'AC', 'EMR', '45', 'EFMR7', 'N', 'RNW', 'ACE23', '7BDFM', 'BDFMNQRW', '456', '1237ACENQRSW', 'EFMR'}

# %% [markdown]
# 5.Okay, so we understand what station represents. But what the heck are C/A, UNIT, and SCP? Keep in mind that in the larger stations, you might have multiple areas within one station that look like this:
#
# <img src="image.jpg" style="width: 300px;"/>
#
# Further complicating things, there are a few station names like 14TH ST that refer to more than one station location along that street.
#
# This data set is not very well documented. Welcome to the joys of real world data science!!!
#
# Read the following two links carefully to see other people's confusion and what information they have been able to gather:
#
# https://groups.google.com/forum/#!topic/mtadeveloperresources/AMVx2WUY9iI
#
# https://groups.google.com/forum/#!searchin/mtadeveloperresources/%22remote$20unit%22%7Csort:relevance/mtadeveloperresources/z8l3ZU9cY6Y/OFlHGkFAimQJ
#
# What did Patrick O'Hara and Katie Toth have to say?

# %%
#insert 5
#C/A = Control Area (A002)
#UNIT = Remote Unit for a station (R051)
#SCP = Subunit Channel Position represents an specific address for a device (02-00-00)

# %% [markdown]
# 6.To simplify our calculations right now, let's only look at ridership on Monday, June 12th, 2017. In one line, create a dataset called monday that just includes the dates listed as 06/12/2017.
#
# Then, use the command "monday = monday.reset_index(drop=True)" to reset the index.

# %%
#insert 6
monday = MTA[MTA.DATE == '06/12/2017']
monday = monday.reset_index(drop=True)
print(monday.head())
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6217322  2104727
# 1  REGULAR  6217332  2104729
# 2  REGULAR  6217372  2104813
# 3  REGULAR  6217540  2105024
# 4  REGULAR  6217825  2105081

# %% [markdown]
# 7.Create a dictionary called monday_dict mapping the tuple (C/A, UNIT,SCP, STATION) to a list of tuples containing (TIME,EXITS).
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') in your dictionary should give the value:
#
# [('00:00:00', 2104727),
#  ('04:00:00', 2104729),
#  ('08:00:00', 2104813),
#  ('12:00:00', 2105024),
#  ('16:00:00', 2105081),
#  ('20:00:00', 2105134)]

# %%
#insert 7
monday_dict = {}
for i in range(len(monday.index)):
    tuple1=(monday['C/A'][i],monday['UNIT'][i],monday['SCP'][i],monday['STATION'][i])
    monday_dict[tuple1]=monday_dict.get(tuple1,[])+[(monday.TIME[i],monday.EXITS[i])]
print(monday_dict['A002', 'R051', '02-00-00','59 ST'])
# Out:
# [('00:00:00', 2104727), ('04:00:00', 2104729), ('08:00:00', 2104813), ('12:00:00', 2105024), ('16:00:00', 2105081), ('20:00:00', 2105134)]

# %% [markdown]
# 8.Note: as you get more comfortable with pandas, you will rely more on built-in pandas capabilities and less on creating dictionaries from scratch. For example, run the following lines of code to verify that this dataframe gives you the same info that you got in Exercise 7.

# %%
x=monday.groupby(['C/A', 'UNIT', 'SCP', 'STATION']).groups #the keys are the station pairs and the values are the row indices
flds = ['TIME','EXITS'] #we want to make values out of the remaining columns
monday_exits = {key: monday.loc[val,flds] for key, val in x.items()}
monday_exits[('A002', 'R051', '02-00-00','59 ST')]
# Out:
#        TIME    EXITS
# 0  00:00:00  2104727
# 1  04:00:00  2104729
# 2  08:00:00  2104813
# 3  12:00:00  2105024
# 4  16:00:00  2105081
# 5  20:00:00  2105134

# %% [markdown]
# 9.What the heck do these exit numbers represent? We can assume that they represent some sort of counter on the turnstile. We can subtract the exits at t=20 minus t=0 to figure out how many riders exited this turnstile between midnight and 8 pm.
#
# Can we calculate 20 - 0 for all of the stations? No! Unfortunately, the time increments aren't standardized. Many of the times are listed in 4 hour intervals of midnight, 4 am, 8 am, etc but not all. Make a frequency chart of the times for the monday dataframe from Exercise 6.

# %%
#insert 9
monday.TIME.value_counts()
# Out:
# 00:00:00    2409
# 12:00:00    2408
# 20:00:00    2408
# 08:00:00    2407
# 04:00:00    2405
# 16:00:00    2405
# 17:00:00    1741
# 13:00:00    1740
# 05:00:00    1740
# 01:00:00    1740
# 09:00:00    1739
# 21:00:00    1738
# 10:00:00     110
# 02:00:00     110
# 22:00:00     110
# 06:00:00     110
# 18:00:00     110
# 14:00:00     110
# 11:00:00      39
# 23:00:00      39
# 07:00:00      39
# 03:00:00      39
# 19:00:00      39
# 15:00:00      39
# 16:22:00      37
# 12:22:00      37
# 08:22:00      37
# 00:22:00      37
# 20:22:00      37
# 04:22:00      37
#             ...
# 04:41:14       1
# 14:58:37       1
# 02:06:49       1
# 06:12:54       1
# 20:59:11       1
# 07:09:22       1
# 06:18:49       1
# 00:58:50       1
# 22:27:24       1
# 02:55:39       1
# 22:09:43       1
# 12:13:54       1
# 05:46:00       1
# 10:58:25       1
# 19:38:36       1
# 16:21:26       1
# 12:02:25       1
# 16:52:08       1
# 18:46:43       1
# 05:18:55       1
# 14:53:33       1
# 04:41:48       1
# 13:27:38       1
# 17:35:05       1
# 08:50:31       1
# 13:17:56       1
# 06:48:57       1
# 04:15:49       1
# 14:12:36       1
# 08:01:54       1
# Name: TIME, Length: 1887, dtype: int64

# %% [markdown]
# 10.Use your monday_dict from Exercise 7 to create a dictionary called monday_dict_diff that maps (C/A, UNIT, SCP, STATION) to the differences in exits between two consective times in order to see how many people exited through a turnstile within a given time interval.
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') should map to:
#
# [('04:00:00', 2),
#  ('08:00:00', 84),
#  ('12:00:00', 211),
#  ('16:00:00', 57),
#  ('20:00:00', 53)]

# %%
#insert 10
monday_dict_diff={} 

for key,value in monday_dict.items(): 
    for i in range(0,len(monday_dict[key])-1):
        monday_dict_diff[key]=monday_dict_diff.get(key,[])+[(value[i+1][0],value[i+1][1]-value[i][1])]
        
                                          
print(monday_dict_diff[('A002', 'R051', '02-00-00','59 ST')])
# Out:
# [('04:00:00', 2), ('08:00:00', 84), ('12:00:00', 211), ('16:00:00', 57), ('20:00:00', 53)]

# %% [markdown]
# 11.Once again, note that pandas can do the above calculation for you. If you used the monday_exits dataframe from Exercise 8, run the following code to verify that you obtain what you just got in Exercise 10. It may take a bit longer to run.

# %%
monday_diff = {}

for turnstile, slice_df in monday_exits.items():
    diff = slice_df['EXITS'].diff().values #calculates the exit difference between each entry
    monday_diff[turnstile] = pd.Series(diff, index=slice_df['TIME'].values) #maps turnstile to (time, exit difference) pairs
    for i,(key, val) in enumerate(monday_diff[turnstile].items()):
        try: #need a try because you'll get an error for NAN difference values since there is one less difference than the number of times
            monday_exits[turnstile].at[i,'EXITS'] = val
        except:
            continue
    monday_exits[turnstile] = monday_exits[turnstile].drop(0)    #drop the first time because you only calculate differences after the second time.                   
    
monday_exits[('A002', 'R051', '02-00-00', '59 ST')]
# Out:
#        TIME  EXITS
# 1  04:00:00      2
# 2  08:00:00     84
# 3  12:00:00    211
# 4  16:00:00     57
# 5  20:00:00     53

# %% [markdown]
# 12.Find how many people in total passed through a given turnstile between the hours given for 06/12/2017. For example, if a turnstile is on increments of 0,4,8,...,20, then you want to find out how many total people passed through between midnight and 8 pm. Create a dictionary called total_turnstile that maps (C/A,UNIT,SCP,STATION) to total Monday ridership. Use your dictionary from Exercise 10.
#
# Hint: the key ('A002', 'R051', '02-00-00', '59 ST') should map to 407 total riders.

# %%
#insert 12
total_turnstile={}

for key,value in monday_dict_diff.items():
    sums=0
    for tuples in value:
        sums+=tuples[1]
    total_turnstile[key]=sums
    
print(total_turnstile['A002', 'R051', '02-00-00', '59 ST'])
# Out:
# 407

# %% [markdown]
# 13.Use your work in Exercise 12 to create a dictionary called total_riders that maps the (C/A, UNIT, STATION) location to all riders that passed through ALL of the turnstiles in that area on Monday.
#
# Hint 1: use the get command
#
# Hint 2: ('A002', 'R051', '59 ST') should have 6704 total riders.

# %%
#insert 13
total_riders={}
for key, value in total_turnstile.items():
    new_tuple=(key[0],key[1],key[3])
    total_riders[new_tuple]=total_riders.get(new_tuple,0)+value
print(total_riders['A002', 'R051', '59 ST'])
# Out:
# 6704

# %% [markdown]
# 14.Create a list of tuples called tuple_list using your total_riders dictionary so that you can sort the list in decending order to see busiest stations. Hint: the busiest area should be the PATH World Trade Center station.

# %%
#insert 14
tuple_list=[]
num=0
name=''
for key,value in total_riders.items():
    num=value
    name=key[2]
    tuple_list.append((num,name))
print(sorted(tuple_list,reverse=True))
# Out:
# [(56297, 'PATH NEW WTC'), (50291, 'GRD CNTRL-42 ST'), (39654, 'GRD CNTRL-42 ST'), (31126, '86 ST'), (27180, '47-50 STS ROCK'), (26181, '34 ST-PENN STA'), (25527, '34 ST-HERALD SQ'), (24776, 'FLUSHING-MAIN'), (24129, '14 ST-UNION SQ'), (24085, '34 ST-HERALD SQ'), (24053, '34 ST-HERALD SQ'), (24049, '59 ST COLUMBUS'), (23536, 'BEDFORD AV'), (23504, '14 ST-UNION SQ'), (23196, 'LEXINGTON AV/53'), (23123, 'W 4 ST-WASH SQ'), (22670, 'JKSN HT-ROOSVLT'), (22189, '42 ST-PORT AUTH'), (22075, '47-50 STS ROCK'), (21168, '125 ST'), (20911, '96 ST'), (20589, '14 ST-UNION SQ'), (20076, 'TIMES SQ-42 ST'), (19889, 'PAVONIA/NEWPORT'), (19870, 'THIRTY THIRD ST'), (19814, 'GRD CNTRL-42 ST'), (19367, 'TIMES SQ-42 ST'), (19271, 'NEWARK HM HE'), (19260, 'JAMAICA CENTER'), (19161, 'GROVE STREET'), (19090, '42 ST-BRYANT PK'), (18894, '77 ST'), (18671, '34 ST-PENN STA'), (18496, 'CHAMBERS ST'), (18491, '59 ST COLUMBUS'), (18132, 'ATL AV-BARCLAY'), (17924, '34 ST-HERALD SQ'), (17543, 'FULTON ST'), (17058, '34 ST-PENN STA'), (16808, 'SUTPHIN-ARCHER'), (16332, 'EXCHANGE PLACE'), (16073, 'CANAL ST'), (16069, 'SOUTH FERRY'), (15975, '68ST-HUNTER CO'), (15842, '61 ST WOODSIDE'), (15761, '72 ST'), (15604, '82 ST-JACKSON H'), (15369, 'CITY / BUS'), (15354, '5 AV/53 ST'), (15312, 'TIMES SQ-42 ST'), (15311, '125 ST'), (15209, 'PARKCHESTER'), (15189, 'KEW GARDENS'), (14887, "B'WAY-LAFAYETTE"), (14793, 'JUNCTION BLVD'), (14219, '72 ST-2 AVE'), (14214, 'TIMES SQ-42 ST'), (13967, 'CANAL ST'), (13952, 'BOWLING GREEN'), (13934, 'GRAND ST'), (13920, '34 ST-PENN STA'), (13916, '42 ST-BRYANT PK'), (13586, 'CROWN HTS-UTICA'), (13442, 'LEXINGTON AV/53'), (13093, '5 AV/53 ST'), (13014, '42 ST-PORT AUTH'), (12945, '168 ST'), (12901, '145 ST'), (12688, '23 ST'), (12645, '59 ST'), (12450, '50 ST'), (12232, '1 AV'), (12130, '8 AV'), (11951, 'THIRTY ST'), (11948, 'FULTON ST'), (11948, '51 ST'), (11942, 'FLUSHING-MAIN'), (11883, '57 ST'), (11850, '8 AV'), (11811, 'TWENTY THIRD ST'), (11630, 'LACKAWANNA'), (
#returns: [(-45421, 'JOURNAL SQUARE'), (-2060, 'GRD CNTRL-42 ST'), (-333, '116 ST')]
#This makes sense because it's caused by a difference by time. The only explanation is that there was an even bigger
#number the day before, so the numbers are skewed.

del tuple_list[:3]
print(tuple_list[:3])
# Out:
# [(0, '161/YANKEE STAD'), (0, '161/YANKEE STAD'), (0, '18 AV')]

# %% [markdown]
# 16.Create a barchart for the number of riders. You don't need to keep track of the names of each station, as that would get really messy to plot. Instead, you can just use a list comprehension to save the rider numbers to the y-values and give the stations the numbers 0,1,2,3,... for the x-values. You can use the following piece of code. Remember to add in axis labels and a title.
#
# x = range(len(tuple_list))
#
# y = [tuple_list[i][0] for i in range(len(tuple_list))]
#
# plt.bar(x,y)

# %%
#insert 16
import matplotlib.pyplot as plt
# %matplotlib inline

x = range(len(tuple_list))

y = [tuple_list[i][0] for i in range(len(tuple_list))]

plt.bar(x,y)
plt.xlabel('Station number');
plt.ylabel('Number of passengers');
plt.title('Passenger distribution by stations');

# %% [markdown]
# 17.Perhaps we don't care about total ridership in a 24-hour period. Perhaps we only care about the morning commute. Let's assume that the majority of people arrive at their work location subway exit between 8 and 9 am.
#
# Go back up to your frequency chart in Exercise 9. Note that the most common morning commutes would be gained from subtracting 9 am - 5 am and 10 am - 6 am and 11 am - 7 am and 12pm - 8am, for the stations that are broken down by those specific four hour intervals.
#
# As a dirty way to consider only the stations that are on these time intervals, save just the rows in your original monday dataframe that contain the TIME strings '05:00:00', '06:00:00',..., '12:00:00'. Remember you can do this by using OR statements using the "|" symbol and remembering parenthesis. Call this new dataframe "morning". Be sure to reset its index.

# %%
#insert 17
morning = monday[(monday.TIME=='05:00:00')|(monday.TIME=='06:00:00')|(monday.TIME=='07:00:00')|(monday.TIME=='08:00:00')|(monday.TIME=='09:00:00')|(monday.TIME=='10:00:00')|(monday.TIME=='11:00:00')|(monday.TIME=='12:00:00')]
morning = morning.reset_index(drop=True)
morning.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  08:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/12/2017  12:00:00
# 2  A002  R051  02-00-01   59 ST  NQR456W      BMT  06/12/2017  08:00:00
# 3  A002  R051  02-00-01   59 ST  NQR456W      BMT  06/12/2017  12:00:00
# 4  A002  R051  02-03-00   59 ST  NQR456W      BMT  06/12/2017  08:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6217372  2104813
# 1  REGULAR  6217540  2105024
# 2  REGULAR  5615730  1247491
# 3  REGULAR  5615864  1247619
# 4  REGULAR   926883  3436892

# %% [markdown]
# 18.Now create a morning_dict by repeating your work in Exercise 7 on this morning dataframe. The dictionary should map the tuple (C/A, UNIT, SCP,STATION) to an inner dictionary containing {TIME: EXITS} for all Monday rides.
#
# Hint: ('A002', 'R051', '02-00-00','59 ST') should map to {'08:00:00': 2104813, '12:00:00': 2105024}.

# %%
#insert 18
morning_dict={}
for i in range(len(morning.index)):
    inner_dictionary={}
    inner_dictionary[morning.TIME[i]]=morning.EXITS[i]
    tuple1=(morning['C/A'][i],morning['UNIT'][i],morning['SCP'][i],morning['STATION'][i])
    if tuple1 not in morning_dict.keys():
        morning_dict[tuple1]=morning_dict.get(tuple1,inner_dictionary)
    else:
        morning_dict[tuple1][morning.TIME[i]]=morning.EXITS[i]
    #print(morning_dict)
print(morning_dict['A002', 'R051', '02-00-00','59 ST'])
# Out:
# {'08:00:00': 2104813, '12:00:00': 2105024}

# %% [markdown]
# 19.We're almost ready to subtract the two consecutive times for each station to get the morning commutes. That is, if there are exactly two times for each station. Find which stations keys in your dictionary above do not contain exactly two times and delete them from the morning dictionary.
#
# How many keys are left in your morning_dict? There should be 4293.

# %%
#insert 19
to_delete=[]
for key,value in morning_dict.items():
    if len(value) !=2:
        to_delete.append(key)
for i in to_delete:
    del morning_dict[i]
print(len(morning_dict))
#('N103', 'R127', '00-06-01', 'JAY ST-METROTEC') [('12:00:00', 1553758)]
#('PTH22', 'R540', '02-05-06', 'PATH NEW WTC') [('12:00:00', 93913)]
#('R245', 'R051', '00-05-00', '59 ST') [('08:00:00', 9353185)]
#('R302', 'R324', '01-00-01', '116 ST') [('05:00:00', 433218)]
#('R307', 'R207', '01-00-02', '135 ST') [('12:00:00', 8667318)]
#('R501', 'R054', '00-00-00', '5 AVE') [('08:00:00', 284255)]
# Out:
# 4293

# %% [markdown]
# 20.Create a dictionary called morning_differences where (C/A, UNIT, STATION) maps to an inner dictionary containing {SCP: Morning Exit Differences}.
#
# For example, ('A002', 'R051', '59 ST') should map to:
#
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %%
#insert 20
morning_differences = {}
for key,value in morning_dict.items():
    newkey = (key[0],key[1],key[3])
    val = []
    SCP = key[2]
    for key1, val1 in value.items():
        val.append(val1)
    dif = val[1]-val[0]
    if newkey not in morning_differences:
        morning_differences[newkey] = {SCP : dif}
    else:
        morning_differences[newkey][SCP] = dif
morning_differences[ ('A002', 'R051', '59 ST')]
# Out:
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %% [markdown]
# 21.Create a dictionary called total_morning_diff that maps each (C/A, Unit, Station) location to the total morning riders passing through ALL of the turnstiles in that area.
#
# Hint 1: see your work in Exercise 13.
#
# Hint 2: ('A002', 'R051','59 ST') should have 2804 morning commuter exits.

# %%
#insert 21
total_morning_diff = {}
for key,value in morning_differences.items():
    som = 0
    for key1,value1 in value.items():
        if key not in total_morning_diff:
            total_morning_diff[key] = int(som) + int(value1)
        else:
            total_morning_diff[key] = total_morning_diff[key]+value1
total_morning_diff[('R238', 'R046', 'GRD CNTRL-42 ST')]
# Out:
# 17300

# %% [markdown]
# 22.Create a list of sorted tuples to see the most popular morning exits.
#
# Hint:  ('R238', 'R046', 'GRD CNTRL-42 ST') should be the highest with 17,300 morning exits.

# %%
#insert 22
sortedtup = []
for key,value in total_morning_diff.items():
    sortedtup.append((value,key))
print(sorted(sortedtup, reverse = True))
# Out:
# [(17300, ('R238', 'R046', 'GRD CNTRL-42 ST')), (16250, ('N500', 'R020', '47-50 STS ROCK')), (13194, ('N501', 'R020', '47-50 STS ROCK')), (12576, ('N306', 'R017', 'LEXINGTON AV/53')), (12545, ('R240', 'R047', 'GRD CNTRL-42 ST')), (10593, ('N504', 'R021', '42 ST-BRYANT PK')), (10213, ('A025', 'R023', '34 ST-HERALD SQ')), (9605, ('N304', 'R015', '5 AV/53 ST')), (9393, ('A021', 'R032', 'TIMES SQ-42 ST')), (9234, ('N505', 'R022', '34 ST-HERALD SQ')), (8903, ('R249', 'R179', '86 ST')), (8893, ('N051', 'R084', '59 ST COLUMBUS')), (8049, ('R116', 'R030', 'CHAMBERS ST')), (7708, ('N049', 'R084', '59 ST COLUMBUS')), (7641, ('N303', 'R015', '5 AV/53 ST')), (7423, ('N305', 'R017', 'LEXINGTON AV/53')), (7155, ('N507', 'R023', '34 ST-HERALD SQ')), (6820, ('R143', 'R032', 'TIMES SQ-42 ST')), (6776, ('R151', 'R033', 'TIMES SQ-42 ST')), (6531, ('N506', 'R022', '34 ST-HERALD SQ')), (6373, ('R145', 'R032', 'TIMES SQ-42 ST')), (6360, ('N098', 'R028', 'FULTON ST')), (6251, ('N503', 'R021', '42 ST-BRYANT PK')), (6194, ('N501A', 'R020', '47-50 STS ROCK')), (6187, ('R155', 'R116', '50 ST')), (5974, ('R243', 'R049', '51 ST')), (5929, ('N520', 'R240', 'GRAND ST')), (5856, ('R245A', 'R051', '59 ST')), (5727, ('R206', 'R014', 'FULTON ST')), (5708, ('R202', 'R042', 'BOWLING GREEN')), (5696, ('R258', 'R132', '125 ST')), (5512, ('R236', 'R045', 'GRD CNTRL-42 ST')), (5392, ('R182', 'R035', '168 ST')), (5309, ('R246', 'R177', '68ST-HUNTER CO')), (5046, ('A033', 'R170', '14 ST-UNION SQ')), (5020, ('N509', 'R203', '23 ST')), (5009, ('R111', 'R027', 'WALL ST')), (4932, ('R210', 'R044', 'BROOKLYN BRIDGE')), (4864, ('R533', 'R055', 'FLUSHING-MAIN')), (4847, ('N092', 'R029', 'CHAMBERS ST')), (4754, ('N305A', 'R016', 'LEXINGTON AV/53')), (4751, ('N508', 'R453', '23 ST')), (4658, ('N083', 'R138', 'W 4 ST-WASH SQ')), (4650, ('R201', 'R041', 'BOWLING GREEN')), (4635, ('R204', 'R043', 'WALL ST')), (4617, ('R154', 'R116', '50 ST')), (4571, ('R113', 'R028', 'FULTON ST')), (4544, ('A022', 'R022', '34 ST-HERALD SQ')), (4440, ('R244', 'R050', '59 ST')), (4376, ('N102', 'R127', 'JAY ST-METROTEC')), (4346, ('R221', 'R170', '14 ST-UNION SQ')), (4336, ('R237', 'R046', 'GRD CNTRL-42 ST')), (4324, ('R247', 'R178', '77 ST')), (4312, ('H009', 'R235', 'BEDFORD AV')), (4305, ('R550', 'R072', '34 ST-HUDSON YD')), (4305, ('N089', 'R139', 'CANAL ST')), (4266, ('A034', 'R170', '14 ST-UNION SQ')), (4171, ('N601', 'R319', 'LEXINGTON AV/63')), (4108, ('R244A', 'R050', '59 ST')), (4094, ('N600', 'R302', '57 ST')), (3965, ('N606', 'R025', 'JAMAICA CENTER')), (3875, ('N067', 'R012', '34 ST-PENN STA')), (3862, ('N301', 'R113', '7 AV')), (3853, ('R110', 'R027', 'WALL ST')), (3841, ('N103', 'R127', 'JAY ST-METROTEC')), (3775, ('R501', 'R054', '5 AVE')), (3765, ('R601A', 'R108', 'BOROUGH HALL')), (3747, ('R142', 'R293', '34 ST-PENN STA')), (3721, ('N091', 'R029', 'CHAMBERS ST')), (3628, ('N062A', 'R010', '42 ST-PORT AUTH')), (3611, ('N094', 'R029', 'WORLD TRADE CTR')), (3580, ('N502', 'R021', '42 ST-BRYANT PK')), (3575, ('N700A', 'R570', '72 ST-2 AVE')), (3555, ('N026', 'R102', '125 ST')), (3499, ('R158', 'R084', '59 ST COLUMBUS')), (3495, ('N095A', 'R014', 'FULTON ST')), (3481, ('N060', 'R010', '42 ST-PORT AUTH')), (3446, ('R147', 'R033', 'TIMES SQ-42 ST')), (3410, ('R169', 'R168', '96 ST')), (3382, ('R516', 'R291', '33 ST-RAWSON ST')), (3378, ('R148', 'R033', 'TIMES SQ-42 ST')), (3347, ('R610', 'R057', 'ATL AV-BARCLAY')), (3343, ('R112', 'R027', 'WALL ST')), (3340, ('R200A', 'R041', 'BOWLING GREEN')), (3315, ('N324', 'R018', 'JKSN HT-ROOSVLT')), (3307, ('A006', 'R079', '5 AV/59 ST')), (3302, ('R242', 'R049', '51 ST')), (3285, ('N605', 'R024', 'SUTPHIN-ARCHER')), (3270, ('N400A', 'R359', 'COURT SQ')), (3210, ('N700', 'R570', '72 ST-2 AVE')), (3204, ('R526', 'R096', '82 ST-JACKSON H')), (3158, ('H008', 'R248', '1 AV')), (3143, ('R228', 'R143', '28 ST')), (3075, ('A042', 'R086', 'PRINCE ST')), (3066, ('A029', 'R082', '28 ST')), (3040, ('A031', 'R083', '23 ST')), (3026, ('N090', 'R139', 'CANAL ST')), ...

# %% [markdown]
# 23.We notice that the ('R204', 'R043', 'WALL ST') stop is pretty high on the Monday morning list. How can we tell if this exit is more of a commuter or tourist exit? Maybe we'll see if the total number of people is higher on a weekday than a weekend. Go back to the original df dataframe. Save only the items that contain ('R204', 'R043', 'WALL ST') to a dataframe called wallstreet and create a list of tuples where the first entry is the date and the second entry is the total ridership.
#
# Hint: there should be 9936 riders on 06/15/2017.

# %%
#insert 23
wallstreet = df[(df['C/A'] == 'R204') 
                & (df['UNIT'] == 'R043')
                & (df['STATION'] == 'WALL ST')]
wallstreet = wallstreet.reset_index(drop=True)

wall_dict={}
for i in range(len(wallstreet.index)):
    mytuple = wallstreet.DATE[i]
    if mytuple not in wall_dict.keys():
        wall_dict[mytuple]={wallstreet.SCP[i]:{wallstreet.TIME[i]:wallstreet.EXITS[i]}}
    if wallstreet.SCP[i] not in wall_dict[mytuple].keys():
         wall_dict[mytuple][wallstreet.SCP[i]]={wallstreet.TIME[i]:wallstreet.EXITS[i]}
    else:
        wall_dict[mytuple][wallstreet.SCP[i]][wallstreet.TIME[i]]=wallstreet.EXITS[i]
#print(wall_dict['06/12/2017'])

wall_exits = {}
for date,turnstile_info in wall_dict.items():
    for turnstile,exit_info in turnstile_info.items():
        start = wall_dict[date][turnstile][sorted(exit_info)[0]]
        end = wall_dict[date][turnstile][sorted(exit_info)[-1]]
        if date not in wall_exits.keys():
            wall_exits[date]={}
        wall_exits[date][turnstile]=end-start
print(wall_dict['06/12/2017'])

tuple_list = []
for date, turnstiles in wall_exits.items():
    count = 0 
    for exit in turnstiles.values():
        count = count + exit
    tuple_list.append((date, count))
tuple_list.sort()
tuple_list
# Out:
# {'02-00-00': {'02:00:00': 4077482, '06:00:00': 4077513, '10:00:00': 4078185, '14:00:00': 4078445, '18:00:00': 4078695, '22:00:00': 4078870}, '02-00-01': {'02:00:00': 3793526, '06:00:00': 3793561, '10:00:00': 3794179, '14:00:00': 3794350, '18:00:00': 3794538, '22:00:00': 3794706}, '02-03-00': {'02:00:00': 3128134, '06:00:00': 3128148, '10:00:00': 3129230, '14:00:00': 3129631, '18:00:00': 3129962, '22:00:00': 3130137}, '02-03-01': {'02:00:00': 817631, '06:00:00': 817635, '10:00:00': 818066, '14:00:00': 818204, '18:00:00': 818305, '22:00:00': 818358}, '02-03-02': {'02:00:00': 439118, '06:00:00': 439120, '10:00:00': 439474, '14:00:00': 439570, '18:00:00': 439641, '22:00:00': 439685}, '02-03-03': {'02:00:00': 877221, '06:00:00': 877225, '10:00:00': 877650, '14:00:00': 877819, '18:00:00': 877932, '22:00:00': 878003}, '02-05-00': {'02:00:00': 751942, '06:00:00': 751954, '10:00:00': 752377, '14:00:00': 752605, '18:00:00': 752819, '22:00:00': 752985}, '02-05-01': {'02:00:00': 235226335, '06:00:00': 235226344, '10:00:00': 235226521, '14:00:00': 235226601, '18:00:00': 235226662, '22:00:00': 235226707}, '02-06-00': {'02:00:00': 17929050, '06:00:00': 17929067, '10:00:00': 17929453, '14:00:00': 17929734, '18:00:00': 17930015, '22:00:00': 17930185}, '02-06-01': {'02:00:00': 252878, '06:00:00': 252881, '10:00:00': 252948, '14:00:00': 252977, '18:00:00': 253046, '22:00:00': 253078}}

# %% [markdown]
# 24.Plot the list of tuples you made where date is the x-axis and ridership is the y-axis for this wall street station.
#
# Hint: you'll first need to use datetime to convert the dates to datetime format.

# %%
#insert 24

import matplotlib.pyplot as plt
# %matplotlib inline

plt.xlabel('Date')
plt.ylabel('Ridership')
plt.show()

# %% [markdown]
# 25.Now use datetime to convert the dates to "Mon", "Tues", etc and print the days of the week with corresponding ridership. Is this a commuter stop or a tourist stop?

# %%
#insert 25
